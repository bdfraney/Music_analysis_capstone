# %%
import pandas as pd, requests
from bs4 import BeautifulSoup
from selenium import webdriver
from time import sleep
import random as rd

# %%
def music_scrape(base_url, start_page=1, end_page=None):
    options = webdriver.ChromeOptions()
    prefs = {'download.default_directory' : 'C:\\Users\\flake\\OneDrive\\Documents\\ga_dsi\\Capstone_Project\\data'}
    options.add_experimental_option('prefs', prefs)
    driver = webdriver.Chrome(executable_path="./chromedriver/windows/chromedriver.exe", options=options)
    page = 0
    try: 
        for i in range(start_page, end_page + 1):
            url = base_url + str(start_page + page)
            print(url)
            driver.get(url)
            response = requests.get(url)
            data = driver.find_element_by_class_name("playlist")
            songList = data.find_elements_by_class_name('icn-arrow')
            page +=1 
        
            for item in songList:
                sleep(rd.randrange(1,10))
#                 print(item.get_attribute('href'))
                driver.get(item.get_attribute('href'))
                
    except:
        driver.close()
        url = base_url + str(start_page + page)
        print(url + ' ' + f"Failed: Error {response}")
        sleep(20)
        music_scrape(base_url, start_page=(start_page + page), end_page=end_page)

# %%
url = 'https://freemusicarchive.org/genre/House/?sort=track_date_published&d=1&page='

music_scrape(url, start_page=1, end_page=40)
# Out:
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=92
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=93
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=94
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=95
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=96
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=97
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=98 Failed: Error <Response [500]>
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=98
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=98 Failed: Error <Response [503]>
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=98
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=98 Failed: Error <Response [503]>
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=98
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=98 Failed: Error <Response [503]>
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=98
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=99
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=100
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=101
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=102
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=103
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=104
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=105 Failed: Error <Response [500]>
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=105
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=105 Failed: Error <Response [503]>
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=105
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=105 Failed: Error <Response [503]>
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=105
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=105 Failed: Error <Response [503]>
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=105
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=106
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=107
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=108
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=109
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=110
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=111
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=112 Failed: Error <Response [200]>
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=112
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=112 Failed: Error <Response [500]>
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=112
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=112 Failed: Error <Response [503]>
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=112
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=112 Failed: Error <Response [503]>
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=112
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=113
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=114
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=115
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=116
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=117
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=118 Failed: Error <Response [200]>
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=118
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=118 Failed: Error <Response [500]>
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=118
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=118 Failed: Error <Response [503]>
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=118
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=118 Failed: Error <Response [503]>
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=118
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=119
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=120
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=121
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=122
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=122 Failed: Error <Response [200]>
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=122
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=122 Failed: Error <Response [200]>
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=122
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=122 Failed: Error <Response [200]>
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=122
# https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page=122 Failed: Error <Response [200]>
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      19 #                 print(item.get_attribute('href'))
# ---> 20                 driver.get(item.get_attribute('href'))
#      21
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webelement.py in get_attribute(self, name)
#     142         else:
# --> 143             resp = self._execute(Command.GET_ELEMENT_ATTRIBUTE, {'name': name})
#     144             attributeValue = resp.get('value')
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=75.0.3770.142)
#   (Driver info: chromedriver=2.41.578737 (49da6702b16031c40d63e5618de03a32ff6c197e),platform=Windows NT 10.0.17763 x86_64)
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      12             response = requests.get(url)
# ---> 13             data = driver.find_element_by_class_name("playlist")
#      14             songList = data.find_elements_by_class_name('icn-arrow')
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"class name","selector":"playlist"}
#   (Session info: chrome=75.0.3770.142)
#   (Driver info: chromedriver=2.41.578737 (49da6702b16031c40d63e5618de03a32ff6c197e),platform=Windows NT 10.0.17763 x86_64)
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      12             response = requests.get(url)
# ---> 13             data = driver.find_element_by_class_name("playlist")
#      14             songList = data.find_elements_by_class_name('icn-arrow')
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"class name","selector":"playlist"}
#   (Session info: chrome=75.0.3770.142)
#   (Driver info: chromedriver=2.41.578737 (49da6702b16031c40d63e5618de03a32ff6c197e),platform=Windows NT 10.0.17763 x86_64)
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      12             response = requests.get(url)
# ---> 13             data = driver.find_element_by_class_name("playlist")
#      14             songList = data.find_elements_by_class_name('icn-arrow')
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"class name","selector":"playlist"}
#   (Session info: chrome=75.0.3770.142)
#   (Driver info: chromedriver=2.41.578737 (49da6702b16031c40d63e5618de03a32ff6c197e),platform=Windows NT 10.0.17763 x86_64)
#
#
# During handling of the above exception, another exception occurred:
#
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      19 #                 print(item.get_attribute('href'))
# ---> 20                 driver.get(item.get_attribute('href'))
#      21
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webelement.py in get_attribute(self, name)
#     142         else:
# --> 143             resp = self._execute(Command.GET_ELEMENT_ATTRIBUTE, {'name': name})
#     144             attributeValue = resp.get('value')
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=75.0.3770.142)
#   (Driver info: chromedriver=2.41.578737 (49da6702b16031c40d63e5618de03a32ff6c197e),platform=Windows NT 10.0.17763 x86_64)
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      12             response = requests.get(url)
# ---> 13             data = driver.find_element_by_class_name("playlist")
#      14             songList = data.find_elements_by_class_name('icn-arrow')
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"class name","selector":"playlist"}
#   (Session info: chrome=75.0.3770.142)
#   (Driver info: chromedriver=2.41.578737 (49da6702b16031c40d63e5618de03a32ff6c197e),platform=Windows NT 10.0.17763 x86_64)
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      12             response = requests.get(url)
# ---> 13             data = driver.find_element_by_class_name("playlist")
#      14             songList = data.find_elements_by_class_name('icn-arrow')
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"class name","selector":"playlist"}
#   (Session info: chrome=75.0.3770.142)
#   (Driver info: chromedriver=2.41.578737 (49da6702b16031c40d63e5618de03a32ff6c197e),platform=Windows NT 10.0.17763 x86_64)
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      12             response = requests.get(url)
# ---> 13             data = driver.find_element_by_class_name("playlist")
#      14             songList = data.find_elements_by_class_name('icn-arrow')
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"class name","selector":"playlist"}
#   (Session info: chrome=75.0.3770.142)
#   (Driver info: chromedriver=2.41.578737 (49da6702b16031c40d63e5618de03a32ff6c197e),platform=Windows NT 10.0.17763 x86_64)
#
#
# During handling of the above exception, another exception occurred:
#
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      19 #                 print(item.get_attribute('href'))
# ---> 20                 driver.get(item.get_attribute('href'))
#      21
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webelement.py in get_attribute(self, name)
#     142         else:
# --> 143             resp = self._execute(Command.GET_ELEMENT_ATTRIBUTE, {'name': name})
#     144             attributeValue = resp.get('value')
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=75.0.3770.142)
#   (Driver info: chromedriver=2.41.578737 (49da6702b16031c40d63e5618de03a32ff6c197e),platform=Windows NT 10.0.17763 x86_64)
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      12             response = requests.get(url)
# ---> 13             data = driver.find_element_by_class_name("playlist")
#      14             songList = data.find_elements_by_class_name('icn-arrow')
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"class name","selector":"playlist"}
#   (Session info: chrome=75.0.3770.142)
#   (Driver info: chromedriver=2.41.578737 (49da6702b16031c40d63e5618de03a32ff6c197e),platform=Windows NT 10.0.17763 x86_64)
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      12             response = requests.get(url)
# ---> 13             data = driver.find_element_by_class_name("playlist")
#      14             songList = data.find_elements_by_class_name('icn-arrow')
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"class name","selector":"playlist"}
#   (Session info: chrome=75.0.3770.142)
#   (Driver info: chromedriver=2.41.578737 (49da6702b16031c40d63e5618de03a32ff6c197e),platform=Windows NT 10.0.17763 x86_64)
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      12             response = requests.get(url)
# ---> 13             data = driver.find_element_by_class_name("playlist")
#      14             songList = data.find_elements_by_class_name('icn-arrow')
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"class name","selector":"playlist"}
#   (Session info: chrome=75.0.3770.142)
#   (Driver info: chromedriver=2.41.578737 (49da6702b16031c40d63e5618de03a32ff6c197e),platform=Windows NT 10.0.17763 x86_64)
#
#
# During handling of the above exception, another exception occurred:
#
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      19 #                 print(item.get_attribute('href'))
# ---> 20                 driver.get(item.get_attribute('href'))
#      21
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webelement.py in get_attribute(self, name)
#     142         else:
# --> 143             resp = self._execute(Command.GET_ELEMENT_ATTRIBUTE, {'name': name})
#     144             attributeValue = resp.get('value')
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=75.0.3770.142)
#   (Driver info: chromedriver=2.41.578737 (49da6702b16031c40d63e5618de03a32ff6c197e),platform=Windows NT 10.0.17763 x86_64)
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      12             response = requests.get(url)
# ---> 13             data = driver.find_element_by_class_name("playlist")
#      14             songList = data.find_elements_by_class_name('icn-arrow')
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"class name","selector":"playlist"}
#   (Session info: chrome=75.0.3770.142)
#   (Driver info: chromedriver=2.41.578737 (49da6702b16031c40d63e5618de03a32ff6c197e),platform=Windows NT 10.0.17763 x86_64)
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      12             response = requests.get(url)
# ---> 13             data = driver.find_element_by_class_name("playlist")
#      14             songList = data.find_elements_by_class_name('icn-arrow')
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"class name","selector":"playlist"}
#   (Session info: chrome=75.0.3770.142)
#   (Driver info: chromedriver=2.41.578737 (49da6702b16031c40d63e5618de03a32ff6c197e),platform=Windows NT 10.0.17763 x86_64)
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      12             response = requests.get(url)
# ---> 13             data = driver.find_element_by_class_name("playlist")
#      14             songList = data.find_elements_by_class_name('icn-arrow')
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"class name","selector":"playlist"}
#   (Session info: chrome=75.0.3770.142)
#   (Driver info: chromedriver=2.41.578737 (49da6702b16031c40d63e5618de03a32ff6c197e),platform=Windows NT 10.0.17763 x86_64)
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      12             response = requests.get(url)
# ---> 13             data = driver.find_element_by_class_name("playlist")
#      14             songList = data.find_elements_by_class_name('icn-arrow')
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"class name","selector":"playlist"}
#   (Session info: chrome=75.0.3770.142)
#   (Driver info: chromedriver=2.41.578737 (49da6702b16031c40d63e5618de03a32ff6c197e),platform=Windows NT 10.0.17763 x86_64)
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      12             response = requests.get(url)
# ---> 13             data = driver.find_element_by_class_name("playlist")
#      14             songList = data.find_elements_by_class_name('icn-arrow')
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"class name","selector":"playlist"}
#   (Session info: chrome=75.0.3770.142)
#   (Driver info: chromedriver=2.41.578737 (49da6702b16031c40d63e5618de03a32ff6c197e),platform=Windows NT 10.0.17763 x86_64)
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      12             response = requests.get(url)
# ---> 13             data = driver.find_element_by_class_name("playlist")
#      14             songList = data.find_elements_by_class_name('icn-arrow')
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"class name","selector":"playlist"}
#   (Session info: chrome=75.0.3770.142)
#   (Driver info: chromedriver=2.41.578737 (49da6702b16031c40d63e5618de03a32ff6c197e),platform=Windows NT 10.0.17763 x86_64)
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      12             response = requests.get(url)
# ---> 13             data = driver.find_element_by_class_name("playlist")
#      14             songList = data.find_elements_by_class_name('icn-arrow')
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# ~\Anaconda3\envs\GA_DSI\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"class name","selector":"playlist"}
#   (Session info: chrome=75.0.3770.142)
#   (Driver info: chromedriver=2.41.578737 (49da6702b16031c40d63e5618de03a32ff6c197e),platform=Windows NT 10.0.17763 x86_64)
#
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-4e69f97ef967> in <module>
#       1 url = 'https://freemusicarchive.org/genre/Techno/?sort=track_date_published&d=1&page='
#       2
# ----> 3 music_scrape(url, start_page=92, end_page=123)
#
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      25         print(url + ' ' + f"Failed: Error {response}")
#      26         sleep(20)
# ---> 27         music_scrape(base_url, start_page=(start_page + page), end_page=end_page)
#
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      25         print(url + ' ' + f"Failed: Error {response}")
#      26         sleep(20)
# ---> 27         music_scrape(base_url, start_page=(start_page + page), end_page=end_page)
#
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      25         print(url + ' ' + f"Failed: Error {response}")
#      26         sleep(20)
# ---> 27         music_scrape(base_url, start_page=(start_page + page), end_page=end_page)
#
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      25         print(url + ' ' + f"Failed: Error {response}")
#      26         sleep(20)
# ---> 27         music_scrape(base_url, start_page=(start_page + page), end_page=end_page)
#
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      25         print(url + ' ' + f"Failed: Error {response}")
#      26         sleep(20)
# ---> 27         music_scrape(base_url, start_page=(start_page + page), end_page=end_page)
#
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      25         print(url + ' ' + f"Failed: Error {response}")
#      26         sleep(20)
# ---> 27         music_scrape(base_url, start_page=(start_page + page), end_page=end_page)
#
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      25         print(url + ' ' + f"Failed: Error {response}")
#      26         sleep(20)
# ---> 27         music_scrape(base_url, start_page=(start_page + page), end_page=end_page)
#
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      25         print(url + ' ' + f"Failed: Error {response}")
#      26         sleep(20)
# ---> 27         music_scrape(base_url, start_page=(start_page + page), end_page=end_page)
#
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      25         print(url + ' ' + f"Failed: Error {response}")
#      26         sleep(20)
# ---> 27         music_scrape(base_url, start_page=(start_page + page), end_page=end_page)
#
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      25         print(url + ' ' + f"Failed: Error {response}")
#      26         sleep(20)
# ---> 27         music_scrape(base_url, start_page=(start_page + page), end_page=end_page)
#
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      25         print(url + ' ' + f"Failed: Error {response}")
#      26         sleep(20)
# ---> 27         music_scrape(base_url, start_page=(start_page + page), end_page=end_page)
#
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      25         print(url + ' ' + f"Failed: Error {response}")
#      26         sleep(20)
# ---> 27         music_scrape(base_url, start_page=(start_page + page), end_page=end_page)
#
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      25         print(url + ' ' + f"Failed: Error {response}")
#      26         sleep(20)
# ---> 27         music_scrape(base_url, start_page=(start_page + page), end_page=end_page)
#
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      25         print(url + ' ' + f"Failed: Error {response}")
#      26         sleep(20)
# ---> 27         music_scrape(base_url, start_page=(start_page + page), end_page=end_page)
#
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      25         print(url + ' ' + f"Failed: Error {response}")
#      26         sleep(20)
# ---> 27         music_scrape(base_url, start_page=(start_page + page), end_page=end_page)
#
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      25         print(url + ' ' + f"Failed: Error {response}")
#      26         sleep(20)
# ---> 27         music_scrape(base_url, start_page=(start_page + page), end_page=end_page)
#
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      25         print(url + ' ' + f"Failed: Error {response}")
#      26         sleep(20)
# ---> 27         music_scrape(base_url, start_page=(start_page + page), end_page=end_page)
#
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      25         print(url + ' ' + f"Failed: Error {response}")
#      26         sleep(20)
# ---> 27         music_scrape(base_url, start_page=(start_page + page), end_page=end_page)
#
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      25         print(url + ' ' + f"Failed: Error {response}")
#      26         sleep(20)
# ---> 27         music_scrape(base_url, start_page=(start_page + page), end_page=end_page)
#
# <ipython-input-12-94e51d0b6b4e> in music_scrape(base_url, start_page, end_page)
#      24         url = base_url + str(start_page + page)
#      25         print(url + ' ' + f"Failed: Error {response}")
# ---> 26         sleep(20)
#      27         music_scrape(base_url, start_page=(start_page + page), end_page=end_page)
#
# KeyboardInterrupt:
